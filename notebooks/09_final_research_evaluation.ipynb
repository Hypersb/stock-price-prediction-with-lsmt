# %% [markdown]
# # Final Research Evaluation
#
# Orchestration notebook only. Core logic lives in `ml/research/`.
# Do not fabricate results. Pass a real `FinalResearchConfig` and market data.

# %%
from ml.research.config import tiny_fixture_config, example_research_config
from ml.research.pipeline import run_final_research_evaluation
from ml.research.report import render_final_research_report

# Example: render the awaiting-results template without inventing numbers.
document = render_final_research_report(None)
print(document.title)
print(document.populated_from_results)

# %% [markdown]
# ## Running a tiny local fixture
#
# Replace synthetic frames with provider-loaded OHLCV for production research.

# %%
# Optional local demo with deterministic fixtures (not a claim of market edge):
# from tests.test_final_research_pipeline import _ohlcv
# config = tiny_fixture_config()
# market_data = {symbol: _ohlcv(seed=i) for i, symbol in enumerate(config.symbols)}
# result = run_final_research_evaluation(market_data, config)
# print(result.experiment_id)
# print(render_final_research_report(result).markdown[:500])
